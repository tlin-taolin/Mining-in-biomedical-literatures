# %%
import os
import sys
sys.path.insert(0, 'util/')

import readwrite as rw
import pandas as pd

# %%
root = "data/mp"
in_data_path = os.path.join(root, "phenotypes_id_aligner.csv")
raw_mp = pd.read_csv(in_data_path)

# %%
useful_mp_df = raw_mp[["PhenoID.1", "Phenotype", "Shown_pheno", "Category"]]
useful_mp_df.columns = ["PhenoID", "Phenotype", "Shown_pheno", "Category"]
lines = useful_mp_df.values.tolist()

# %%
from collections import namedtuple

class PhenotypeInfo(object):
    def __init__(self, line):
        self.id = line[0]
        self.phenotype = line[1]
        self.shown_pheno = line[2]
        self.category = line[3]

def build_classes(lines):
    return [PhenotypeInfo(line) for line in lines]

lines_class = build_classes(lines)

# %%
import re

def clean_blank(pheno):
    pheno = filter(lambda x: x != "", pheno.split(" "))
    return " ".join(pheno)


def clean_pheno(line):
    pheno = line.phenotype
    pattern = re.compile("(?:\[.*?\]|\(.*?\))", re.X)
    pheno = re.sub(pattern, "", pheno)
    pheno = clean_blank(pheno)
    line.phenotype = pheno
    return line

def clean_phenos(lines_class):
    return [clean_pheno(line) for line in lines_class]

def get_info(lines_class, v):
    return list(set([getattr(line, v) for line in lines_class]))


def summary_info(lines_class):
    categories = get_info(lines_class, "category")
    shown_phenos = get_info(lines_class, "shown_pheno")
    return categories, shown_phenos

categories, shown_phenos = summary_info(lines_class)
categories
# Out:
# ['Drug response',
#  'Anxiety',
#  'Musculoskeletal system',
#  'Blood chemistry',
#  'Microbiome',
#  'Immune',
#  'Other',
#  'Activity',
#  'Blood metabolites',
#  'Morphology',
#  'Nervous system',
#  'Metabolism']

# %%
import groupby as gp

def group_info(lines_class):
    category_ids = [(line.category, line.id) for line in lines_class]
    shownpheno_ids = [(line.shown_pheno, line.id) for line in lines_class]

    categories_grouped_ids = gp.group_by(category_ids, index=0)
    shownpheno_grouped_ids = gp.group_by(shownpheno_ids, index=0)
    
    return categories_grouped_ids, shownpheno_grouped_ids

categories_grouped_ids, shownpheno_grouped_ids = group_info(lines_class)

# %%
# [(k, [v[1] for v in vv]) for k, vv in categories_grouped_ids]
[(k, [v[1] for v in vv]) for k, vv in shownpheno_grouped_ids]
# Out:
# [('1416531_at (Gsto1) Residual', [1250]),
#  ('2013 Birthdays', [2119]),
#  ('3-nitropropionic acid neurodegeneration in striatum', [1906]),
#  ('ATPase activity (Mg-ATPase) for whole brain homogenate', [3386]),
#  ('ATPase activity (Na+/K+-ATPase) for whole brain homogenate', [3387]),
#  ('ATPase activity (total activity) for whole brain homogenate', [3388]),
#  ('Acesulfame sweet taste response', [1210]),
#  ('Acetaminophen hepatocyte viability response', [2160, 2161, 2162]),
#  ('Acid beta-glucosidase activity_CD', [4081]),
#  ('Acid beta-glucosidase activity_CD+HFD', [2120]),
#  ('Acid beta-glucosidase activity_HFD', [4080]),
#  ('Acinetobacter baumannii infection', [2053]),
#  ('Acoustic startle response',
#   [3595,
#    3596,
#    3597,
#    3598,
#    239,
#    240,
#    241,
#    242,
#    243,
#    244,
#    245,
#    2742,
#    246,
#    2743,
#    2744,
#    247,
#    3268,
#    2770,
#    293,
#    294,
#    2771,
#    2772,
#    2773,
#    2774,
#    295,
#    2775,
#    2776,
#    296,
#    2777,
#    2778,
#    297,
#    2779,
#    2780,
#    298,
#    2781,
#    2782,
#    299,
#    300,
#    248]),
#  ('Actinobacteria (class) frequency', [169]),
#  ('Actinobacteria (phylum) frequency', [170]),
#  ('Actinobacteridae (subclass) frequency', [171]),
#  ('Actinomycetales (order) frequency', [172]),
#  ('Activity (ambulations) (night)_CD_AUC', [2173]),
#  ('Activity (ambulations) (night)_HFD_AUC', [2172]),
#  ('Activity (movement) (24 hours)_CD', [1778]),
#  ('Activity (movement) (24 hours)_HFD', [5]),
#  ('Activity (movement) (day)_CD', [1779]),
#  ('Activity (movement) (day)_HFD', [1780]),
#  ('Activity (movement) (night)_CD', [1777]),
#  ('Activity (movement) (night)_CD_AUC', [2170]),
#  ('Activity (movement) (night)_HFD', [4]),
#  ('Activity (movement) (night)_HFD_AUC', [2171]),
#  ('Activity (rearing) (24 hours)_CD', [1782]),
#  ('Activity (rearing) (24 hours)_HFD', [7]),
#  ('Activity (rearing) (day)_CD', [3804]),
#  ('Activity (rearing) (day)_HFD', [3805]),
#  ('Activity (rearing) (night)_CD', [1781]),
#  ('Activity (rearing) (night)_HFD', [6]),
#  ('Activity (rearing) at night_CD_AUC', [4112]),
#  ('Activity (rearing) at night_HFD_AUC', [4113]),
#  ('Acute locomotor baseline activity response', [3361]),
#  ('Acyl chain length in liver', [2257]),
#  ('Acyl chain length in muscle', [4154]),
#  ('Acyl chain length in reproductive adipose tissue', [2261]),
#  ('Adipose tissue hanging at the intestine', [4155, 4156, 4157]),
#  ('Adrenal X-zone width', [2758, 272, 273]),
#  ('Adrenal gland weight', [3939, 1931]),
#  ('Adrenal medulla width', [268, 2756, 267]),
#  ('Adrenal total weight', [269, 270]),
#  ('Adrenal weight', [814, 810, 809, 811, 813, 812]),
#  ('Adrenal weight difference', [3940]),
#  ('Adrenal width', [2757, 271]),
#  ('Adrenal zona fasciculata width', [275, 2759, 274]),
#  ('Adrenal zona glomerulosa width', [2760, 2761]),
#  ('Adrenal zona intermedia width', [276, 2762]),
#  ('Adrenal zona reticularis width', [277, 2763]),
#  ('Aerococcaceae (family) frequency', [2682]),
#  ('Aerococcus (genus) frequency', [2683]),
#  ('Age at death of hippocampal samples', [4152]),
#  ('Age-related T-cell decline', [3183, 3184, 3185, 3186]),
#  ('Aggregate FRET', [3923]),
#  ('Air control response', [1925, 1926, 3796, 1760]),
#  ('Airway bronchial constrictor response', [1101]),
#  ('Airway inflammatory response', [1145, 3338]),
#  ('Alanine transaminase', [3572, 3573, 3574]),
#  ('Alanine transaminase, female', [99]),
#  ('Alanine transaminase, male', [100]),
#  ('Alanine transaminase_CD', [3553]),
#  ('Alanine transaminase_HFD', [3554]),
#  ('Alanine_CD', [1253]),
#  ('Alanine_CD+HFD', [1252]),
#  ('Alanine_HFD', [3422]),
#  ('Albumin, female', [101]),
#  ('Albumin, male', [102]),
#  ('Albuminuria concentration', [4114]),
#  ('Alcohol response',
#   [2504, 4426, 4427, 4428, 2505, 2506, 4429, 4430, 4431, 4432]),
#  ('Alistipes (genus) frequency', [173]),
#  ('Alkaline phosphatase, female', [103]),
#  ('Alkaline phosphatase, male', [104]),
#  ('Alkaline phosphatase_CD', [1393]),
#  ('Alkaline phosphatase_HFD', [1394]),
#  ('Allopregnanolone response', [3189, 3190]),
#  ('Alpha-aminoadipate/lysine_CD', [13]),
#  ('Alpha-aminoadipate/lysine_CD+HFD', [11]),
#  ('Alpha-aminoadipate/lysine_HFD', [12]),
#  ('Alpha-aminoadipate_CD', [10]),
#  ('Alpha-aminoadipate_CD+HFD', [8]),
#  ('Alpha-aminoadipate_HFD', [9]),
#  ('Alpha-amylase, female', [105]),
#  ('Alpha-amylase, male', [2627]),
#  ('Amphetamine response', [3389, 1125, 1126]),
#  ('Amygdala volume', [2995]),
#  ('Amygdala, basolateral complex volume', [878, 879]),
#  ('Amygdala, glial cell density', [3061]),
#  ('Amygdala, glial cell number', [3062, 877]),
#  ('Amygdala, neuron cell density', [3063]),
#  ('Amygdala, neuron number', [3065, 3064]),
#  ('Amygdala, non-neuronal cell number', [3067, 3066]),
#  ('Amygdala, total cell number', [3068, 3069]),
#  ('Amylase_CD', [1395]),
#  ('Amylase_HFD', [1396]),
#  ('Androgenetic blastocysts percentage', [1098]),
#  ('Anergy', [1180]),
#  ('Anterior commissure volume', [823]),
#  ('Anterior pretectal nucleus volume', [2994]),
#  ('Anti-F antigen (liver protein) titer', [1207, 1208]),
#  ('Antibody IgG1 response', [3084]),
#  ('Antigenic activity of spleen cells',
#   [1234, 1235, 1236, 1239, 1237, 3411, 1238]),
#  ('Antinociceptive responsive', [1128]),
#  ('Anxiety', [1823]),
#  ('Anxiety assay',
#   [3600,
#    1806,
#    1460,
#    1807,
#    1808,
#    1809,
#    1810,
#    1811,
#    3836,
#    1812,
#    1461,
#    1813,
#    1814,
#    1462,
#    1815,
#    1816,
#    3837,
#    1817,
#    1818,
#    3838,
#    1819,
#    1471,
#    1472,
#    1473,
#    1463,
#    1464,
#    1474,
#    1465,
#    1466,
#    1467,
#    3839,
#    3840,
#    1468,
#    3031,
#    1475,
#    1476,
#    1477,
#    1478,
#    3601,
#    1479,
#    1480,
#    1481,
#    1482,
#    1483,
#    3602,
#    1484,
#    3603,
#    1485,
#    3604,
#    1486,
#    3605,
#    1487,
#    3606,
#    1488,
#    1489,
#    3607,
#    3608,
#    3841,
#    3609,
#    3610,
#    3611,
#    3612,
#    3613,
#    3614,
#    3032,
#    302,
#    304,
#    303,
#    305,
#    306,
#    307,
#    3617,
#    3842,
#    1490,
#    3615,
#    3616,
#    3843,
#    1820,
#    3618,
#    1821,
#    1491,
#    1492,
#    3619,
#    1493,
#    3620,
#    1494,
#    1495,
#    3621,
#    1496,
#    3622,
#    3623,
#    3624,
#    1497,
#    1498,
#    3625,
#    3626,
#    1499,
#    3627,
#    1822,
#    3628,
#    308,
#    2783,
#    2785,
#    2784,
#    857,
#    3014,
#    1500,
#    858,
#    3015,
#    309,
#    311,
#    310,
#    3033,
#    312,
#    859,
#    2786,
#    2787,
#    2788,
#    313,
#    2789,
#    1501,
#    1502,
#    3629,
#    3630,
#    1503,
#    3631,
#    1504,
#    3632,
#    1505,
#    3633,
#    1506,
#    3634,
#    1507,
#    3635,
#    1508,
#    1509,
#    3636,
#    3637,
#    3638,
#    1510,
#    1511,
#    3639,
#    3640,
#    3641,
#    1512,
#    1513,
#    3642,
#    1514,
#    3643,
#    3644,
#    3645,
#    3646,
#    1515,
#    3647,
#    1516,
#    3648,
#    1517,
#    3649,
#    1518,
#    3650,
#    3651,
#    1519,
#    3652,
#    1520,
#    3653,
#    3654,
#    3655,
#    3656,
#    3657,
#    3658,
#    3659,
#    1521,
#    3660,
#    3661,
#    3662,
#    3663,
#    3664,
#    3665,
#    3666,
#    1522,
#    1523,
#    3667,
#    1524,
#    3668,
#    3669,
#    3670,
#    1525,
#    1526,
#    1527,
#    1528,
#    1529,
#    1530,
#    1531,
#    1532,
#    1533,
#    3671,
#    1534,
#    3672,
#    1535,
#    1536,
#    3673,
#    3674,
#    3675,
#    1537,
#    3676,
#    3677,
#    3678,
#    1538,
#    3679,
#    3680,
#    337,
#    2790,
#    314,
#    315,
#    2791,
#    316,
#    2792,
#    317,
#    2793,
#    2794,
#    318,
#    2795,
#    319,
#    2796,
#    320,
#    3016,
#    2797,
#    321,
#    322,
#    323,
#    2798,
#    324,
#    860,
#    3034,
#    325,
#    327,
#    326,
#    328,
#    2799,
#    329,
#    330,
#    2801,
#    2800,
#    2802,
#    2804,
#    2803,
#    331,
#    2805,
#    332,
#    333,
#    334,
#    2806,
#    335,
#    2807,
#    336,
#    3681,
#    1539,
#    1540]),
#  ('Aortic atherosclerotic lesions', [943]),
#  ('Apoptosis in cortex', [1913, 1914]),
#  ('Apoptosis of breast tumor cells', [949, 950]),
#  ('Apoptosis of the hippocampus', [1583]),
#  ('Arginine in plasma_CD ', [3483]),
#  ('Arginine in plasma_CD+HFD', [1301]),
#  ('Arginine in plasma_HFD ', [1302]),
#  ('Arginine vasopressin transcript abundance in total hypothalamic RNA',
#   [3086]),
#  ('Asparagine_CD', [1254]),
#  ('Asparagine_CD+HFD', [3423]),
#  ('Asparagine_HFD', [3424]),
#  ('Aspartate in plasma_CD ', [1305]),
#  ('Aspartate in plasma_CD+HFD', [1303]),
#  ('Aspartate in plasma_HFD ', [1304]),
#  ('Aspartate transaminase, female', [2628]),
#  ('Aspartate transaminase, male', [2629]),
#  ('Aspartate transaminase_CD', [3555]),
#  ('Aspartate transaminase_HFD', [3556]),
#  ('Astrocyte cell number percentage', [958]),
#  ('Astrocyte differentiation in culture', [3576]),
#  ('Audiogeneic seizure, relative frequency', [1223]),
#  ('Audiogenic seizure incidence', [1227]),
#  ('Audiogenic seizure severity', [1228]),
#  ('Audiogenic seizure severity score', [1224]),
#  ('Audiogenic seizure susceptibility and severity', [1229]),
#  ('Autoimmune disease',
#   [3093, 3094, 907, 3095, 908, 3096, 3097, 3098, 3099, 3100, 3101, 909]),
#  ('Average path length to reach the platform', [3174]),
#  ('B cells as a percentage of CD45+ cells', [4006]),
#  ('B cells as a percentage of MHC class II (I/A-E) cells', [1995]),
#  ('B-mannosidase activity in kidney', [1204]),
#  ('B-mannosidase activity in liver', [1203]),
#  ('BCAA/Alanine in plasma_CD', [1356]),
#  ('BCAA/Alanine in plasma_CD+HFD', [1354]),
#  ('BCAA/Alanine in plasma_HFD', [1355]),
#  ('BCAA/C3-carnitine in plasma_CD', [3514]),
#  ('BCAA/C3-carnitine in plasma_CD+HFD', [1357]),
#  ('BCAA/C3-carnitine in plasma_HFD', [3513]),
#  ('BCAA/Glutamine in plasma_CD', [3517]),
#  ('BCAA/Glutamine in plasma_CD+HFD', [3515]),
#  ('BCAA/Glutamine in plasma_HFD', [3516]),
#  ('BCAA/amino acid in plasma_CD', [1360]),
#  ('BCAA/amino acid in plasma_CD+HFD', [1358]),
#  ('BCAA/amino acid in plasma_HFD', [1359]),
#  ('BXD epoch batch trait 1', [1953]),
#  ('BXD epoch batch trait 2', [1954]),
#  ('BXD epoch batch trait 3', [1955]),
#  ('BXD epoch batch trait 4', [1956]),
#  ('Bacillales (order) proportion', [174]),
#  ('Bacilli (class) frequency', [175]),
#  ('Bacterial load', [4018, 4026]),
#  ('Bacteroidaceae (family) proportion', [176]),
#  ('Bacteroidales (order) frequency', [177]),
#  ('Bacteroides (genus) proportion', [178]),
#  ('Bacteroidetes (class) frequency', [179]),
#  ('Bacteroidetes (phylum) frequency', [180]),
#  ('Baculum shape factor 1', [4466]),
#  ('Barnsiella (OTU) proportion', [2684]),
#  ('Basal glucose_CD', [1397]),
#  ('Basal glucose_HFD', [1398]),
#  ('Basolateral amygdala residual volume', [73]),
#  ('Basophils, percentage_CD', [1957]),
#  ('Basophils, percentage_HFD', [3957]),
#  ('Basophils_CD', [1958]),
#  ('Basophils_HFD', [3958]),
#  ('Batch processing lot number for BXD Lung expression', [2253]),
#  ('Bile acids_CD', [1399]),
#  ('Bile acids_HFD', [3557]),
#  ('Bilirubin_CD', [3558]),
#  ('Bilirubin_HFD', [1400]),
#  ('Blood glucose', [3146, 3147, 3141, 3142, 3143, 3144]),
#  ('Blood proteins, female', [2630]),
#  ('Blood proteins, male', [106]),
#  ('Blood urea nitrogen', [1251, 3421]),
#  ('Body fat mass percentage, female', [2667]),
#  ('Body fat mass percentage, male', [2668]),
#  ('Body fat mass, female', [2665]),
#  ('Body fat mass, male', [2666]),
#  ('Body lean mass percentage, female', [2670]),
#  ('Body lean mass percentage, male', [135]),
#  ('Body lean mass, female', [134]),
#  ('Body lean mass, male', [2669]),
#  ('Body length', [4158, 2262, 2263, 4159, 2264, 4160, 4161, 4162, 4163]),
#  ('Body temperature', [3214, 1244]),
#  ('Body temperature 1 hour in 4 deg C chamber_HFD', [4130]),
#  ('Body temperature 2 hours in 4 deg C chamber_CD', [2222]),
#  ('Body temperature 2 hours in 4 deg C chamber_HFD', [2223]),
#  ('Body temperature 3 hours in 4 deg C chamber_CD', [2224]),
#  ('Body temperature 3 hours in 4 deg C chamber_HFD', [4131]),
#  ('Body temperature 4 hours in 4 deg C chamber_CD', [2225]),
#  ('Body temperature 4 hours in 4 deg C chamber_HFD', [4132]),
#  ('Body temperature 5 hours in 4 deg C chamber_CD', [2226]),
#  ('Body temperature 5 hours in 4 deg C chamber_HFD', [4133]),
#  ('Body temperature 6 hours in 4 deg C chamber_CD', [2227]),
#  ('Body temperature 6 hours in 4 deg C chamber_HFD', [4134]),
#  ('Body temperature 6 hours in 4 deg C chamber_HFD/CD', [2228]),
#  ('Body temperature baseline', [945]),
#  ('Body temperature baseline, female', [3148]),
#  ('Body temperature baseline, male', [3149]),
#  ('Body temperature loss between 3 to 6 hours after being placed in 4 deg C chamber_CD',
#   [4136]),
#  ('Body temperature loss between 3 to 6 hours after being placed in 4 deg C chamber_HFD',
#   [2232]),
#  ('Body temperature loss, 3 hours in 4 deg C chamber_CD', [2229]),
#  ('Body temperature loss, 3 hours in 4 deg C chamber_HFD', [2230]),
#  ('Body temperature loss, 6 hours in 4 deg C chamber_CD', [2231]),
#  ('Body temperature loss, 6 hours in 4 deg C chamber_HFD', [4135]),
#  ('Body temperature, 1 hour in 4 deg C chamber_CD', [4129]),
#  ('Body temperature, basal_CD', [2233]),
#  ('Body temperature, basal_HFD', [4137]),
#  ('Body temperature, basal_HFD/CD', [4138]),
#  ('Body temperature, female', [2663]),
#  ('Body temperature, male', [2664]),
#  ('Body weight',
#   [4045,
#    83,
#    3289,
#    1541,
#    3682,
#    3683,
#    3684,
#    1542,
#    1543,
#    1544,
#    3685,
#    3688,
#    3686,
#    3687,
#    3689,
#    2735,
#    2736,
#    2737,
#    2738,
#    2721,
#    2739,
#    2258,
#    990,
#    3135,
#    84]),
#  ('Body weight 10 weeks in female on HFD', [4182]),
#  ('Body weight 10 weeks in female+male on HFD ', [2283]),
#  ('Body weight 10 weeks in male on HFD ', [2284]),
#  ('Body weight 11 weeks in female on HFD', [2285]),
#  ('Body weight 11 weeks in female+male on HFD ', [4183]),
#  ('Body weight 11 weeks in male on HFD ', [2286]),
#  ('Body weight 12 weeks in female on HFD', [2287]),
#  ('Body weight 12 weeks in female+male on HFD ', [4184]),
#  ('Body weight 12 weeks in male on HFD ', [2288]),
#  ('Body weight 13 weeks in female on HFD', [2289]),
#  ('Body weight 13 weeks in female+male on HFD ', [4185]),
#  ('Body weight 13 weeks in male on HFD ', [2290]),
#  ('Body weight 14 weeks in female on HFD', [2291]),
#  ('Body weight 14 weeks in female+male on HFD ', [4186]),
#  ('Body weight 14 weeks in male on HFD ', [4187]),
#  ('Body weight 15 weeks in female on HFD ', [2265]),
#  ('Body weight 15 weeks in female+male on HFD ', [4164]),
#  ('Body weight 15 weeks in male on HFD ', [4165]),
#  ('Body weight 16 weeks in female on HFD', [2266]),
#  ('Body weight 16 weeks in female+male on HFD ', [4166]),
#  ('Body weight 16 weeks in male on HFD ', [4167]),
#  ('Body weight 17 weeks in female on HFD', [2267]),
#  ('Body weight 17 weeks in female+male on HFD ', [4168]),
#  ('Body weight 17 weeks in male on HFD ', [4169]),
#  ('Body weight 18 weeks in female on HFD', [2268]),
#  ('Body weight 18 weeks in female+male on HFD ', [4170]),
#  ('Body weight 18 weeks in male on HFD ', [4171]),
#  ('Body weight 19 weeks in female on HFD', [2269]),
#  ('Body weight 19 weeks in female+male on HFD ', [4172]),
#  ('Body weight 19 weeks in male on HFD ', [4173]),
#  ('Body weight 20 weeks in female on HFD', [2270]),
#  ('Body weight 20 weeks in female+male on HFD ', [4174]),
#  ('Body weight 20 weeks in male on HFD ', [4175]),
#  ('Body weight 28 weeks in female on HFD', [2272]),
#  ('Body weight 28 weeks in female+male on HFD ', [2271]),
#  ('Body weight 28 weeks in male on HFD ', [2273]),
#  ('Body weight 5 weeks in female on HFD', [4176]),
#  ('Body weight 5 weeks in female+male on HFD ', [2274]),
#  ('Body weight 5 weeks in male on HFD ', [4177]),
#  ('Body weight 6 weeks in female on HFD', [4178]),
#  ('Body weight 6 weeks in female+male on HFD ', [2275]),
#  ('Body weight 6 weeks in male on HFD ', [2276]),
#  ('Body weight 7 weeks in female on HFD', [4179]),
#  ('Body weight 7 weeks in female+male on HFD ', [2277]),
#  ('Body weight 7 weeks in male on HFD ', [2278]),
#  ('Body weight 8 weeks in female on HFD', [4180]),
#  ('Body weight 8 weeks in female+male on HFD ', [2279]),
#  ('Body weight 8 weeks in male on HFD ', [2280]),
#  ('Body weight 9 weeks in female on HFD', [4181]),
#  ('Body weight 9 weeks in female+male on HFD ', [2281]),
#  ('Body weight 9 weeks in male on HFD ', [2282]),
#  ('Body weight at sacrifice_CD', [2187]),
#  ('Body weight at sacrifice_HFD', [4119]),
#  ('Body weight fat loss percentage after exercise_CD', [2189]),
#  ('Body weight fat loss percentage after exercise_HFD', [4121]),
#  ('Body weight gain 10-11 weeks, female on HFD', [4188]),
#  ('Body weight gain 10-11 weeks, female+male on HFD', [2292]),
#  ('Body weight gain 10-11 weeks, male on HFD', [4189]),
#  ('Body weight gain 11-12 weeks, female on HFD', [2294]),
#  ('Body weight gain 11-12 weeks, female+male on HFD', [2293]),
#  ('Body weight gain 11-12 weeks, male on HFD', [2295]),
#  ('Body weight gain 12-13 weeks, female on HFD', [2296]),
#  ('Body weight gain 12-13 weeks, female+male on HFD', [4190]),
#  ('Body weight gain 12-13 weeks, male on HFD', [2297]),
#  ('Body weight gain 13-14 weeks, female on HFD', [2299]),
#  ('Body weight gain 13-14 weeks, female+male on HFD', [2298]),
#  ('Body weight gain 13-14 weeks, male on HFD', [4191]),
#  ('Body weight gain 14-15 weeks, female on HFD', [4192]),
#  ('Body weight gain 14-15 weeks, female+male on HFD', [2300]),
#  ('Body weight gain 14-15 weeks, male on HFD', [4193]),
#  ('Body weight gain 15-16 weeks, female on HFD', [2302]),
#  ('Body weight gain 15-16 weeks, female+male on HFD', [2301]),
#  ('Body weight gain 15-16 weeks, male on HFD', [4194]),
#  ('Body weight gain 16-17 weeks, female on HFD', [2303]),
#  ('Body weight gain 16-17 weeks, female+male on HFD', [4195]),
#  ('Body weight gain 16-17 weeks, male on HFD', [4196]),
#  ('Body weight gain 17-18 weeks, female on HFD', [2304]),
#  ('Body weight gain 17-18 weeks, female+male on HFD', [4197]),
#  ('Body weight gain 17-18 weeks, male on HFD', [2305]),
#  ('Body weight gain 18-19 weeks, female on HFD', [4199]),
#  ('Body weight gain 18-19 weeks, female+male on HFD', [4198]),
#  ('Body weight gain 18-19 weeks, male on HFD', [4200]),
#  ('Body weight gain 19-20 weeks, female on HFD', [2306]),
#  ('Body weight gain 19-20 weeks, female+male on HFD', [4201]),
#  ('Body weight gain 19-20 weeks, male on HFD', [2307]),
#  ('Body weight gain 4-5 weeks, female on HFD', [2308]),
#  ('Body weight gain 4-5 weeks, female+male on HFD', [4202]),
#  ('Body weight gain 4-5 weeks, male on HFD', [4203]),
#  ('Body weight gain 5-6 weeks, female on HFD', [4204]),
#  ('Body weight gain 5-6 weeks, female+male on HFD', [2309]),
#  ('Body weight gain 5-6 weeks, male on HFD', [2310]),
#  ('Body weight gain 6-7 weeks, female on HFD', [2311]),
#  ('Body weight gain 6-7 weeks, female+male on HFD', [4205]),
#  ('Body weight gain 6-7 weeks, male on HFD', [4206]),
#  ('Body weight gain 7-8 weeks, female on HFD', [4207]),
#  ('Body weight gain 7-8 weeks, female+male on HFD', [2312]),
#  ('Body weight gain 7-8 weeks, male on HFD', [2313]),
#  ('Body weight gain 8-16 weeks_CD', [2190]),
#  ('Body weight gain 8-16 weeks_HFD', [4122]),
#  ('Body weight gain 8-28 weeks_CD', [2191]),
#  ('Body weight gain 8-28 weeks_HFD', [4123]),
#  ('Body weight gain 8-9 weeks, female on HFD', [4208]),
#  ('Body weight gain 8-9 weeks, female+male on HFD', [2314]),
#  ('Body weight gain 8-9 weeks, male on HFD', [2315]),
#  ('Body weight gain 9-10 weeks, female on HFD', [4210]),
#  ('Body weight gain 9-10 weeks, female+male on HFD', [4209]),
#  ('Body weight gain 9-10 weeks, male on HFD', [4211]),
#  ('Body weight gain percentage 8-16 weeks_HFD', [4124]),
#  ('Body weight gain percentage 8-28 weeks_CD', [2192]),
#  ('Body weight gain percentage 8-28 weeks_HFD', [2193]),
#  ('Body weight in 3-4 month old test naive female.', [3591]),
#  ('Body weight in home cage_CD', [2316]),
#  ('Body weight in home cage_HFD', [2317]),
#  ('Body weight loss percentage after exercise_CD', [4125]),
#  ('Body weight loss percentage after exercise_HFD', [2194]),
#  ('Body weight loss pre-sacrifice_CD', [4126]),
#  ('Body weight loss pre-sacrifice_HFD', [2195]),
#  ('Body weight of adult male', [3419]),
#  ('Body weight percentage gain 8-16 weeks_CD', [4127]),
#  ('Body weight preCLAMS_CD', [14]),
#  ('Body weight preCLAMS_HFD', [2196]),
#  ('Body weight_13-week, female', [149]),
#  ('Body weight_13-week, male', [2675]),
#  ('Body weight_14-week, female', [150]),
#  ('Body weight_14-week, male', [151]),
#  ('Body weight_15-week, female', [2676]),
#  ('Body weight_15-week, male', [2677]),
#  ('Body weight_16 weeks_CD', [2181]),
#  ('Body weight_16 weeks_HFD', [2182]),
#  ('Body weight_16-week, female', [152]),
#  ('Body weight_16-week_CD', [148]),
#  ('Body weight_17 week, female', [132]),
#  ('Body weight_17 week, male', [133]),
#  ('Body weight_17-week, female', [153]),
#  ('Body weight_17-week, male', [2678]),
#  ('Body weight_18-week, female', [137, 154]),
#  ('Body weight_18-week, male', [138, 155]),
#  ('Body weight_19-week, female', [136, 156]),
#  ('Body weight_19-week, male', [2671, 2679]),
#  ('Body weight_20-week, female', [158, 157]),
#  ('Body weight_20-week, male', [2680, 159]),
#  ('Body weight_28 weeks_CD', [2183]),
#  ('Body weight_28 weeks_HFD', [2184]),
#  ('Body weight_8 weeks_CD', [4117]),
#  ('Body weight_8 weeks_HFD', [4118]),
#  ('Body weight_NIBP_CD', [2185]),
#  ('Body weight_NIBP_HFD', [2186]),
#  ('Body weight_PostWheel_CD', [2179]),
#  ('Body weight_PostWheel_HFD', [2180]),
#  ('Body weight_PreWheel_CD', [2188]),
#  ('Body weight_PreWheel_HFD', [4120]),
#  ('Bone mineral content of femur of 10-week-old female', [2414]),
#  ('Bone mineral content of femur of 10-week-old male', [2415]),
#  ('Bone mineral content of tibia of 10-week-old female', [2416]),
#  ('Bone mineral content of tibia of 10-week-old male', [2417]),
#  ('Bone mineral content_19-week, female', [142]),
#  ('Bone mineral content_19-week, male', [143]),
#  ('Bone mineral density', [1090, 983]),
#  ('Bone mineral density in female', [3195]),
#  ('Bone mineral density of femur', [2411, 2413, 2500]),
#  ('Bone mineral density of the tibia', [4281]),
#  ('Bone mineral density of tibia', [4280, 2412]),
#  ('Bone mineral density_19-week, female', [144]),
#  ('Bone mineral density_19-week, male', [145]),
#  ('Bone surface area_19-week, female', [146]),
#  ('Bone surface area_19-week, male', [147]),
#  ('Brain activity and coherence of electrical field oscillations',
#   [3752,
#    1584,
#    1585,
#    3753,
#    1586,
#    3754,
#    3755,
#    3756,
#    3757,
#    1587,
#    3758,
#    3759,
#    1588,
#    1589,
#    1590,
#    1591,
#    1592,
#    1593,
#    3760,
#    3761,
#    3762,
#    3763,
#    1594,
#    1595,
#    1596,
#    1597,
#    1598,
#    1599,
#    1600,
#    1601,
#    1602,
#    1603,
#    1604,
#    1605,
#    1606,
#    1607,
#    1608,
#    1609,
#    1610,
#    3764,
#    3765,
#    1611,
#    1612,
#    1613,
#    1614,
#    1615,
#    3766,
#    3767,
#    3768,
#    1616,
#    1617,
#    1618,
#    1619,
#    3769,
#    1620,
#    1621,
#    1622,
#    1623,
#    1624,
#    1625,
#    1626,
#    1627,
#    1628,
#    1629,
#    1630,
#    1631,
#    1632,
#    1633,
#    1634,
#    1635,
#    1636,
#    1637,
#    1638,
#    1639,
#    1640,
#    1641,
#    1642,
#    1643,
#    1644,
#    1645,
#    1646,
#    1647,
#    1648,
#    1649,
#    1650,
#    1651,
#    1652,
#    1653,
#    1654,
#    1655,
#    1656,
#    1657,
#    1658,
#    1659,
#    1660,
#    1661,
#    1662,
#    1663,
#    1664,
#    1665,
#    1666,
#    1667,
#    3770,
#    1668,
#    1669,
#    1670,
#    1671,
#    1672,
#    1673,
#    1674,
#    1675,
#    1676,
#    1677,
#    1678,
#    1679,
#    1680,
#    1681,
#    1682,
#    1683,
#    1684,
#    1685,
#    1686,
#    1687,
#    1688,
#    1689,
#    1690,
#    1691,
#    1692,
#    1693,
#    1694,
#    1695,
#    1696,
#    1697,
#    1698,
#    1699,
#    3771,
#    1700,
#    3772,
#    3773,
#    1701,
#    3774,
#    1702,
#    1703,
#    3775,
#    3776,
#    1704,
#    1705,
#    1706,
#    1707,
#    1708,
#    1709,
#    1710,
#    1711,
#    1712,
#    1713,
#    1714,
#    1715,
#    1716,
#    1717,
#    1718,
#    1719,
#    1720,
#    1721,
#    1722,
#    1723,
#    3777,
#    3778,
#    3779,
#    3780,
#    1724,
#    3781,
#    3782,
#    1725,
#    3783,
#    3784,
#    3785,
#    3786,
#    3787,
#    3788,
#    3789,
#    1726,
#    1727,
#    1728,
#    1729,
#    3790,
#    1730,
#    1731,
#    1732,
#    1733,
#    1734,
#    3791,
#    1735,
#    3792,
#    3793,
#    1736,
#    1737,
#    3794,
#    1738,
#    1739,
#    1740,
#    1741,
#    1742,
#    1743,
#    1744,
#    1745,
#    1746,
#    1747,
#    1748,
#    1749,
#    3795,
#    1750,
#    1751,
#    1752,
#    1753,
#    1754,
#    1755,
#    1756,
#    1757,
#    1758]),
#  ('Brain ventricle volume', [2996]),
#  ('Brain volume', [825]),
#  ('Brain volume minus cerebellum volume', [824]),
#  ('Brain weight',
#   [988, 1073, 3129, 3131, 3202, 3300, 74, 3042, 995, 75, 76, 77, 1794]),
#  ('Brain weight at 20 weeks, female, HFD', [4213]),
#  ('Brain weight at 20 weeks, male and female, HFD', [4212]),
#  ('Brain weight at 20 weeks, male, HFD', [2318]),
#  ('Brain weight in young adult male', [3418]),
#  ('Brain/body weight', [1245, 1545, 3690, 3691]),
#  ('Brainstem partial volume', [826]),
#  ('BrdU-labeled cells in the rostral migratory stream', [2991, 281, 280]),
#  ('Breeding performance', [2515]),
#  ('Bronchoalveolar lavage lung lymphocyte cell number', [2054]),
#  ('Brown adipose tissue mass_20-week, female', [139]),
#  ('Brown adipose tissue mass_20-week, male', [2672]),
#  ('Brown adipose tissue, female and male, HFD', [4214]),
#  ('Brown adipose tissue, female, HFD', [2319]),
#  ('Brown adipose tissue, male, HFD', [4215]),
#  ('Burkholderia pseudomallei infection response',
#   [2061, 2055, 2056, 2057, 2058, 2059, 2060, 2062]),
#  ('C0-carnitine_CD', [1256]),
#  ('C0-carnitine_CD+HFD', [1255]),
#  ('C0-carnitine_HFD', [3425]),
#  ('C0/C2-carnitine_CD', [3495]),
#  ('C0/C2-carnitine_CD+HFD', [1323]),
#  ('C0/C2-carnitine_HFD', [3494]),
#  ('C10-carnitine_CD', [3427]),
#  ('C10-carnitine_CD+HFD', [3426]),
#  ('C10-carnitine_HFD', [1257]),
#  ('C12-carnitine_CD', [3429]),
#  ('C12-carnitine_CD+HFD', [3428]),
#  ('C12-carnitine_HFD', [1258]),
#  ('C12-hydroxy-carnitine_CD', [3431]),
#  ('C12-hydroxy-carnitine_CD+HFD', [3430]),
#  ('C12-hydroxy-carnitine_HFD', [1259]),
#  ('C12:1-carnitine_CD', [3432]),
#  ('C12:1-carnitine_CD+HFD', [1260]),
#  ('C12:1-carnitine_HFD', [1261]),
#  ('C14-carnitine_CD', [3434]),
#  ('C14-carnitine_CD+HFD', [3433]),
#  ('C14-carnitine_HFD', [1262]),
#  ('C14:1-carnitine_CD', [3437]),
#  ('C14:1-carnitine_CD+HFD', [3435]),
#  ('C14:1-carnitine_HFD', [3436]),
#  ('C14:1-hydroxy-carnitine_CD', [1263]),
#  ('C14:1-hydroxy-carnitine_CD+HFD', [3438]),
#  ('C14:1-hydroxy-carnitine_HFD', [3439]),
#  ('C14:1/C14-carnitine_CD', [1326]),
#  ('C14:1/C14-carnitine_CD+HFD', [1324]),
#  ('C14:1/C14-carnitine_HFD', [1325]),
#  ('C14:1/C2-carnitine_CD', [3498]),
#  ('C14:1/C2-carnitine_CD+HFD', [3496]),
#  ('C14:1/C2-carnitine_HFD', [3497]),
#  ('C14:2-carnitine_CD', [3442]),
#  ('C14:2-carnitine_CD+HFD', [3440]),
#  ('C14:2-carnitine_HFD', [3441]),
#  ('C14:2/C14:1-carnitine_CD', [3499]),
#  ('C14:2/C14:1-carnitine_CD+HFD', [1327]),
#  ('C14:2/C14:1-carnitine_HFD', [1421]),
#  ('C16-carnitine_CD', [3444]),
#  ('C16-carnitine_CD+HFD', [3443]),
#  ('C16-carnitine_HFD', [1264]),
#  ('C16-hydroxy-carnitine_CD', [3446]),
#  ('C16-hydroxy-carnitine_CD+HFD', [3445]),
#  ('C16-hydroxy-carnitine_HFD', [1265]),
#  ('C16:1-carnitine_CD', [3448]),
#  ('C16:1-carnitine_CD+HFD', [3447]),
#  ('C16:1-carnitine_HFD', [1420]),
#  ('C16:1-hydroxy-carnitine_CD', [3449]),
#  ('C16:1-hydroxy-carnitine_CD+HFD', [1266]),
#  ('C16:1-hydroxy-carnitine_HFD', [1267]),
#  ('C16:1/C16-carnitine_CD', [1330]),
#  ('C16:1/C16-carnitine_CD+HFD', [1328]),
#  ('C16:1/C16-carnitine_HFD', [1329]),
#  ('C16:2-carnitine_CD', [3452]),
#  ('C16:2-carnitine_CD+HFD', [3450]),
#  ('C16:2-carnitine_HFD', [3451]),
#  ('C16:2/C16:1-carnitine_CD', [1332]),
#  ('C16:2/C16:1-carnitine_CD+HFD', [1331]),
#  ('C16:2/C16:1-carnitine_HFD', [3500]),
#  ('C18-carnitine_CD', [3453]),
#  ('C18-carnitine_CD+HFD', [1268]),
#  ('C18-carnitine_HFD', [1269]),
#  ('C18:1-carnitine_CD', [3455]),
#  ('C18:1-carnitine_CD+HFD', [3454]),
#  ('C18:1-carnitine_HFD', [1270]),
#  ('C18:1-hydroxy-carnitine_CD', [3457]),
#  ('C18:1-hydroxy-carnitine_CD+HFD', [1271]),
#  ('C18:1-hydroxy-carnitine_HFD', [3456]),
#  ('C18:1/C18-carnitine_CD', [3503]),
#  ('C18:1/C18-carnitine_CD+HFD', [3501]),
#  ('C18:1/C18-carnitine_HFD', [3502]),
#  ('C18:2-carnitine_CD', [3460]),
#  ('C18:2-carnitine_CD+HFD', [3458]),
#  ('C18:2-carnitine_HFD', [3459]),
#  ('C18:2/C18:1-carnitine_CD', [1335]),
#  ('C18:2/C18:1-carnitine_CD+HFD', [1333]),
#  ('C18:2/C18:1-carnitine_HFD', [1334]),
#  ('C2-carnitine-acetylcarnitine_CD', [3463]),
#  ('C2-carnitine-acetylcarnitine_CD+HFD', [3461]),
#  ('C2-carnitine-acetylcarnitine_HFD', [3462]),
#  ('C3 dicarboxylylcarnitine_CD', [1308]),
#  ('C3 dicarboxylylcarnitine_CD+HFD', [1306]),
#  ('C3 dicarboxylylcarnitine_HFD', [1307]),
#  ('C3-carnitine_propionylcarnitine_CD', [1311]),
#  ('C3-carnitine_propionylcarnitine_CD+HFD', [1309]),
#  ('C3-carnitine_propionylcarnitine_HFD', [1310]),
#  ('C4-carnitine_CD', [3486]),
#  ('C4-carnitine_CD+HFD', [3484]),
#  ('C4-carnitine_HFD', [3485]),
#  ('C4-hydroxy-carnitine_CD', [1272]),
#  ('C4-hydroxy-carnitine_CD+HFD', [3464]),
#  ('C4-hydroxy-carnitine_HFD', [3465]),
#  ('C5 dicarboxylylcarnitine_CD', [1275]),
#  ('C5 dicarboxylylcarnitine_CD+HFD', [1273]),
#  ('C5 dicarboxylylcarnitine_HFD', [1274]),
#  ('C5-carnitine_CD', [1313]),
#  ('C5-carnitine_CD+HFD', [1312]),
#  ('C5-carnitine_HFD', [3487]),
#  ('C6-carnitine_CD', [1277]),
#  ('C6-carnitine_CD+HFD', [1276]),
#  ('C6-carnitine_HFD', [3466]),
#  ('C8-carnitine_CD', [3468]),
#  ('C8-carnitine_CD+HFD', [3467]),
#  ('C8-carnitine_HFD', [1278]),
#  ('CD11b+ NKp46+ cells as a percentage of CD5-cells', [2010]),
#  ('CD25+ cells as a percentage of CD3+ CD4+', [1994]),
#  ('CD3+ cells as a percentage of CD45+ cells', [1996]),
#  ('CD3+ gamma/delta TCR+ cells as a percentage of CD45+ cells', [1997]),
#  ('CD3+CD4+ cells as a percentage of CD45+ cells', [1998]),
#  ('CD3+CD8a+ cells as a percentage of CD45+ cells', [4007]),
#  ('CD44+ Ly6C+ cells as a percentage of CD3+ CD8+ cells', [2002]),
#  ('CD44+ cells as a percentage of CD3+ CD4+ without CD62L cells', [1999]),
#  ('CD44+ cells as a percentage of CD3+ CD8+ cells', [4008]),
#  ('CD44+ cells excluding CD62L cells as a percentage of CD8+ CD3+ cells',
#   [2000]),
#  ('CD44+ effector-memory T cells as a percentage of CD3+ CD4+ T cells',
#   [2001]),
#  ('CD5+ cells as a percentage of B cells  ', [4014]),
#  ('CD62L+ T cells without CD44 cells as a percentage of CD3+ CD4+ T cells',
#   [2005]),
#  ('CD62L+ cells as a percentage of CD3+ CD4+ cells', [2003]),
#  ('CD62L+ cells as a percentage of CD3+ CD8+ cells', [4009]),
#  ('CD62L+ cells excluding CD44 cells as a percentage of CD3+CD8+ cells',
#   [2004]),
#  ('CPV map 10', [1915]),
#  ('CPV map 2', [1916]),
#  ('CPV map 3', [4052]),
#  ('CPV map 4', [4053, 2068]),
#  ('CPV map 5', [4054]),
#  ('CPV map 6', [1917]),
#  ('CPV map 7', [2066]),
#  ('CPV map 8', [2067]),
#  ('CPV map 9', [4055]),
#  ('CPV mapping Amanda Data map 1', [3930]),
#  ('Cadmium response', [1196]),
#  ('Cadmium toxicity', [1015]),
#  ('Calcium stimulated NTPase activity in brain microsomes', [1148]),
#  ('Calcium, female', [2631]),
#  ('Calcium, male', [2632]),
#  ('Candida albicans titer in brain', [2589, 2590]),
#  ('Candida albicans titer in kidney', [45]),
#  ('Candida albicans titer, renal', [2591]),
#  ('Cart expression in hypothalamus', [851]),
#  ('Catechol-o-methyl transferase expression', [1763, 278]),
#  ('Cell death in brainstem following exposure to ethanol', [1908, 3926]),
#  ('Cell death in brainstem following exposure to maltose dextrin', [1909]),
#  ('Cell death in forebrain following exposure to ethanol', [3927]),
#  ('Cell death in forebrain following exposure to maltose dextrin', [1910]),
#  ('Cell death in otic vesicles following exposure to ethanol', [1911, 1907]),
#  ('Cell death in otic vesicles following exposure to maltose dextrin', [1759]),
#  ('Cell death in the forebrain following ethanol exposure', [1912]),
#  ('Cell death in untreated brainstem', [3928]),
#  ('Cell death in untreated forebrain', [3929]),
#  ('Cell number in the dorsal striatum', [1795]),
#  ('Cell proliferation in culture', [3577]),
#  ('Cell proliferation in the adult dentate gyrus', [895]),
#  ('Central corneal thickness', [1943]),
#  ('Central motor pattern generation', [195, 196, 197, 2705, 198, 199]),
#  ('Ceramide (d18: 1)_liver_CD', [2123]),
#  ('Ceramide (d18: 1)_liver_CD+HFD', [2121]),
#  ('Ceramide (d18: 1)_liver_HFD', [2122]),
#  ('Ceramide (d18: 1)_plasma_CD', [1281]),
#  ('Ceramide (d18: 1)_plasma_CD+HFD', [1279]),
#  ('Ceramide (d18: 1)_plasma_HFD', [1280]),
#  ('Cerebellar Purkinje cell number', [1796]),
#  ('Cerebellum fissure number', [1146]),
#  ('Cerebellum internal granule layer volume', [996]),
#  ('Cerebellum residual weight', [1797, 78]),
#  ('Cerebellum volume', [3201, 2997, 997]),
#  ('Cerebellum weight', [999, 998]),
#  ('Cerebral cortex grey matter volume', [3070]),
#  ('Cerebral cortex residual volume', [79]),
#  ('Cerebral cortex volume', [818, 827, 819, 894, 3077]),
#  ('Cerebral peduncle volume', [2998]),
#  ('Chlamydia muridarum upper genital tract disease severity', [2015, 2016]),
#  ('Chlamydia psittaci infection respons', [868, 867, 869, 870]),
#  ('Chlolesterol, female', [107]),
#  ('Chlordiazepoxide response', [1082, 1083, 1084, 3287, 1085]),
#  ('Chloride, female', [2633]),
#  ('Chloride, male', [2634]),
#  ('Cholesterol following 16-week high-fat diet', [3139]),
#  ('Cholesterol, male', [97]),
#  ('Cholesterol_CD', [1401]),
#  ('Cholesterol_HFD', [3559]),
#  ('Citrulline_CD', [3470]),
#  ('Citrulline_CD+HFD', [3469]),
#  ('Citrulline_HFD', [1282]),
#  ('Cleft palate frequency ', [1189]),
#  ('Clostridia (class) frequency', [2685]),
#  ('Clostridiales (order) frequency', [2686]),
#  ('Cocaine and amphetamine-regulated transcript expression in hypothalamus',
#   [3025]),
#  ('Cocaine response',
#   [1094,
#    572,
#    2900,
#    2901,
#    573,
#    574,
#    575,
#    2902,
#    576,
#    577,
#    578,
#    2903,
#    2904,
#    579,
#    580,
#    2905,
#    581,
#    2907,
#    2908,
#    2906,
#    582,
#    583,
#    584,
#    587,
#    2909,
#    585,
#    586,
#    588,
#    2910,
#    589,
#    3298,
#    590,
#    592,
#    591,
#    593,
#    595,
#    594,
#    596,
#    598,
#    597,
#    599,
#    601,
#    600,
#    602,
#    603,
#    604,
#    3220,
#    3221,
#    1021,
#    1022,
#    3223,
#    3222,
#    3224,
#    1023,
#    3225,
#    3226,
#    3227,
#    3228,
#    605,
#    607,
#    606,
#    608,
#    610,
#    609,
#    611,
#    612,
#    2911,
#    2913,
#    2912,
#    613,
#    2914,
#    614,
#    615,
#    2915,
#    616,
#    617,
#    2916,
#    618,
#    2917,
#    2919,
#    2918,
#    619,
#    620,
#    621,
#    2920,
#    622,
#    623,
#    626,
#    627,
#    624,
#    625,
#    628,
#    630,
#    629,
#    631,
#    633,
#    632,
#    634,
#    635,
#    2921,
#    2922,
#    636,
#    637,
#    2923,
#    2924,
#    2925,
#    2926,
#    2893,
#    2927,
#    638,
#    568,
#    2928,
#    2894,
#    2929,
#    2930,
#    2895,
#    2931,
#    3229,
#    3230,
#    1024,
#    1025,
#    3231,
#    3232,
#    1027,
#    1026,
#    3233,
#    1028,
#    1029,
#    3234,
#    1158,
#    1157,
#    3353,
#    1095,
#    1096,
#    1031,
#    1030,
#    1032,
#    3235,
#    1033,
#    3236,
#    1035,
#    1034,
#    3237,
#    1036,
#    3239,
#    3238,
#    1037,
#    1097,
#    3240,
#    3242,
#    3241,
#    1039,
#    1038,
#    1040,
#    3299,
#    3243,
#    1042,
#    1041,
#    1043,
#    3244,
#    1134,
#    3215,
#    3216,
#    808,
#    2767]),
#  ('Coccidioides immitis', [1069]),
#  ('Cochlear nuclei volume', [820]),
#  ('Cohort study order_CD [rank]', [4153]),
#  ('Cohort study order_CD [weeks]', [2254]),
#  ('Cohort study order_HFD [rank]', [2255]),
#  ('Cohort study order_HFD [weeks]', [2256]),
#  ('Collagen content', [2320, 2321, 2322]),
#  ('Collagen integrity', [2323, 2324, 2325]),
#  ('Conditioned fear expression', [1456]),
#  ('Conditioned place preference',
#   [2896, 2932, 2897, 639, 2898, 2808, 2809, 338, 2766]),
#  ('Contralateral visual cortex shift', [845]),
#  ('Control for ethanol response',
#   [1889,
#    3898,
#    3899,
#    3900,
#    3901,
#    3902,
#    3903,
#    3904,
#    3905,
#    3906,
#    1890,
#    1891,
#    3907,
#    1893,
#    1892,
#    3908,
#    3909,
#    3910,
#    1927,
#    1928,
#    3936]),
#  ('Control response', [3203, 1007, 3204, 3205, 3206, 981]),
#  ('Copper in dorsal striatum, female', [883]),
#  ('Copper in dorsal striatum, male', [884]),
#  ('Copper in hippocampus', [852, 853]),
#  ('Copper in medial prefrontal cortex, female', [3072]),
#  ('Copper in medial prefrontal cortex, male', [885]),
#  ('Copper in nucleus accumbens, female', [3073]),
#  ('Copper in nucleus accumbens, male', [886]),
#  ('Copper in ventral midbrain, female', [887]),
#  ('Copper in ventral midbrain, male', [888]),
#  ('Coriobacteriaceae (family) frequency', [2687]),
#  ('Coriobacteriales (order) frequency', [2688]),
#  ('Coriobacteridaesub (class) frequency', [2689]),
#  ('Coriobacterineae (suborder) proportion', [2690]),
#  ('Corneal neovascular response to FGF2', [3102, 3103]),
#  ('Corpus callosum volume', [2999]),
#  ('Cortical grey matter volume', [3071]),
#  ('Corticosterone difference in serum', [1922]),
#  ('Corticosterone in plasma', [864]),
#  ('Corticosterone in serum control', [3934]),
#  ('Corticosterone in serum following chronic mild stress', [1923]),
#  ('Corticosterone plasma concentration 1 hr after saline injection', [1129]),
#  ('Corticotropin releasing factor receptor 1 mRNA  abundance in total hypothalamic RNA',
#   [3087]),
#  ('Corticotropin-releasing factor binding protein mRNA expression in total hypothalamic RNA ',
#   [3089]),
#  ('Corticotropin-releasing factor transcript abundance in total hypothalamic RNA ',
#   [3088]),
#  ('Corynebacteriaceae (family) proportion', [2691]),
#  ('Corynebacterineae (suborder) proportion', [181]),
#  ('Corynebacterium (genus) proportion', [2692]),
#  ('Cowpox virus disease onset', [2017]),
#  ('Cowpox virus maximum body temperature', [4048]),
#  ('Cowpox virus maximum weight loss', [2063]),
#  ('Cowpox virus measure of disease onse', [4049, 4050, 4051]),
#  ('Cowpox virus severity of disease', [2064]),
#  ('Cowpox virus survival', [2065]),
#  ('Cox-Hasty trait 1', [4017]),
#  ('Creatine kinase_CD', [1402]),
#  ('Creatine kinase_HFD', [1403]),
#  ('Creatinine, female', [108]),
#  ('Creatinine, male', [2635]),
#  ('Creatinine_CD', [1404]),
#  ('Creatinine_HFD', [1405]),
#  ('Cytosolic AHR protein in liver', [1188]),
#  ('Cytotoxic T-cell response', [924, 925, 3115]),
#  ('Cytotoxicity in spleen T cells 21 days', [3116]),
#  ('Cytotoxicity in spleen T cells 30 days', [3117]),
#  ('Cytotoxicity in spleen T cells 50 days', [926]),
#  ('Cytotoxicity in spleen T cells 7 days', [3118]),
#  ('Deep mesencephalic nuclei volume', [3000]),
#  ('Deoxycorticosterone in blood plasma after control', [262]),
#  ('Deoxycorticosterone in blood plasma after dexamethasone', [2754]),
#  ('Deoxycorticosterone in cerebral cortex after control', [264]),
#  ('Deoxycorticosterone in cerebral cortex after dexamethasone', [263]),
#  ('Depression assay', [871, 861, 339, 341, 340, 2810, 343, 342, 1546]),
#  ('Diabetes model', [2221, 2220, 2174, 4116]),
#  ('Diaphysis bone density of tibia', [2418]),
#  ('Diastolic blood pressure_CD', [1433]),
#  ('Diastolic blood pressure_HFD', [1434]),
#  ('Discrimination test correct responses', [2557]),
#  ('Dock1 mRNA expression in striatum', [3798]),
#  ('Dopamine D1 receptor expression in striatum', [3799]),
#  ('Dopamine D2 receptor expression in striatum', [1764]),
#  ('Dopamine receptor 1 binding maximum',
#   [3245, 3246, 1044, 3247, 1045, 1046, 3248, 3249, 3250, 3251, 1047, 1048]),
#  ('Dopamine receptor 2 binding maximum',
#   [3252, 1049, 1050, 1051, 3253, 1052, 1053, 1054, 3254, 1055, 3255, 1056]),
#  ('Dopamine receptor ratio in striatum', [3800]),
#  ('Dopamine transporter binding maximum',
#   [1057, 1058, 1059, 1060, 1061, 3256, 3257, 3258, 1062, 3259, 3260, 3261]),
#  ('Dopamine transporter protein density', [993]),
#  ('Dorsal lateral geniculate nucleus endothelial cell number', [934]),
#  ('Dorsal lateral geniculate nucleus glial cell number', [3126]),
#  ('Dorsal lateral geniculate nucleus neuron number', [3127]),
#  ('Dorsal lateral geniculate nucleus total cell number', [3128]),
#  ('Dorsal lateral geniculate nucleus volume', [935]),
#  ('Dorsal striatum residual volume', [80]),
#  ('Dorsal thalamus volume', [3060]),
#  ('ELISA-2x, IgG class antibody binding to TSHR A-subunit protein', [2011]),
#  ('ELISA-3x, IgG class antibody binding to TSHR A-subunit protein', [2012]),
#  ('EOMES coefficient', [4057]),
#  ('Ebf1 mRNA expression in striatum', [1765]),
#  ('Ectopia incidence in the neocortex of adults', [1582]),
#  ('Ectromelia virus euthanasia scale', [2069]),
#  ('Ectromelia virus formation of secondary dermal lesions',
#   [2018, 2070, 4027, 4056]),
#  ('Ectromelia virus measure of disease onset', [2071, 2019]),
#  ('Ectromelia virus measure of severity of disease', [2072, 2073]),
#  ('Ectromelia virus mortality score', [2074]),
#  ('Ectromelia virus survival', [2075, 2076]),
#  ('Ectromelia virus-induced mortality', [3410, 1232]),
#  ('Effect of MPTP on 5-HIAA', [3869, 62]),
#  ('Effect of MPTP on 5-HT', [3870, 3871]),
#  ('Effect of MPTP on DOPAC/DA', [3868, 3872, 1849, 1850, 3873]),
#  ('Effect of MPTP on HVA', [1853, 2606, 3875]),
#  ('Effect of MPTP on TH', [1854, 1855]),
#  ('Effect of MPTP on dopamine', [3874, 63, 1851]),
#  ('Effect of MPTP on glial acidic fibrillary protein', [1856, 1852]),
#  ('Eigentrait for TRPC3 expression', [3801]),
#  ('Ejection fraction, female', [2640]),
#  ('Ejection fraction, male', [117]),
#  ('Electrophoretic band variant of ANPEP', [1247]),
#  ('End-diastolic diameter, female', [2641]),
#  ('End-diastolic diameter, male', [2642]),
#  ('End-systolic diameter, female', [2643]),
#  ('End-systolic diameter, male', [2644]),
#  ('Eosinophils, percentage_CD', [3959]),
#  ('Eosinophils, percentage_HFD', [3961]),
#  ('Eosinophils_CD', [3960]),
#  ('Eosinophils_HFD', [3962]),
#  ('Epidermal ornithine decarboxylase (ODC) activity', [1233]),
#  ('Epididymal white adipose mass, percentage_CD', [2404]),
#  ('Epididymal white adipose mass, percentage_HFD', [2405]),
#  ('Epididymal white adipose mass_CD', [4276]),
#  ('Epididymal white adipose mass_HFD', [2403]),
#  ('Erbb4 mRNA expression in hippocampus', [1766]),
#  ('Errors of omission', [232, 233]),
#  ('Erysipelotrichaceae (family) proportion', [2693]),
#  ('Erysipelotrichales (order) proportion', [2694]),
#  ('Erysipelotrichi (class) proportion', [2695]),
#  ('Ethanol acceptance', [3262, 1063, 3263, 3264]),
#  ('Ethanol hepatocyte cytotoxicity response', [4103, 2163, 4104, 4105]),
#  ('Ethanol preference', [1064, 3265, 3266, 3267]),
#  ('Ethanol response',
#   [944,
#    3145,
#    1824,
#    3377,
#    1092,
#    3196,
#    3197,
#    984,
#    985,
#    986,
#    3290,
#    3288,
#    1086,
#    1087,
#    1088,
#    1089,
#    955,
#    3167,
#    843,
#    3168,
#    3169,
#    3170,
#    3844,
#    3845,
#    1825,
#    1826,
#    3846,
#    1160,
#    3356,
#    1167,
#    1161,
#    3847,
#    1168,
#    1182,
#    3378,
#    1162,
#    1827,
#    1153,
#    1154,
#    1155,
#    1137,
#    3327,
#    3367,
#    1169,
#    1170,
#    3368,
#    1172,
#    3369,
#    3328,
#    3329,
#    1138,
#    3330,
#    1139,
#    1147,
#    3339,
#    1135,
#    3331,
#    1173,
#    1174,
#    1175,
#    1176,
#    2933,
#    2934,
#    640,
#    2935,
#    2936,
#    641,
#    3362,
#    1171,
#    3322,
#    2937,
#    642,
#    643,
#    645,
#    644,
#    646,
#    647,
#    2938,
#    648,
#    649,
#    2939,
#    650,
#    652,
#    651,
#    653,
#    655,
#    654,
#    656,
#    657,
#    2940,
#    658,
#    660,
#    659,
#    661,
#    662,
#    2941,
#    663,
#    664,
#    2942,
#    665,
#    2943,
#    666,
#    667,
#    2944,
#    2945,
#    1183,
#    1017,
#    1184,
#    3218,
#    1833,
#    1834,
#    3850,
#    1835,
#    1836,
#    3851,
#    3852,
#    1828,
#    3848,
#    1829,
#    3849,
#    1830,
#    1831,
#    1832,
#    1185,
#    1186,
#    3379,
#    3380,
#    3019,
#    3340,
#    3341,
#    3323,
#    3324,
#    844,
#    1156,
#    3349,
#    3318,
#    3342,
#    3343,
#    1136,
#    3325,
#    2946,
#    2948,
#    2947,
#    2949,
#    668,
#    2950,
#    669,
#    671,
#    670,
#    2951,
#    2952,
#    3360,
#    1163,
#    3911,
#    1894,
#    1895,
#    1896,
#    3912,
#    1897,
#    3913,
#    3914,
#    3853,
#    3854,
#    1837,
#    1838,
#    1839,
#    3915,
#    3916,
#    3917,
#    1898,
#    3918,
#    3919,
#    3920,
#    3921,
#    1141,
#    3332,
#    3333,
#    3334,
#    3855,
#    1840,
#    3357,
#    1899,
#    1900,
#    1901,
#    1093,
#    1018,
#    1902,
#    1140,
#    3856,
#    1841,
#    3857,
#    3858,
#    3859,
#    3860,
#    3861,
#    1842,
#    1903,
#    1904,
#    1905,
#    1144,
#    3350,
#    3291,
#    3182,
#    967,
#    2992,
#    3180,
#    3181,
#    946,
#    3150,
#    1130,
#    3319,
#    3320,
#    1131,
#    3935,
#    1929,
#    3937,
#    1930,
#    3938,
#    3321,
#    2768,
#    3592,
#    3593]),
#  ('Ethanol withdrawal handling induced convulsions', [3307]),
#  ('Extensor digitorum longus muscle weight', [927, 902]),
#  ('Extensor digitorum longus weight', [3090, 928]),
#  ('Extinction learning', [27, 2558, 28, 29, 2559, 30]),
#  ('Eye weight', [1074, 1935, 1075]),
#  ('Fast glucose, female', [98]),
#  ('Fast glucose, male', [2626]),
#  ('Fasting glucose_CD', [1316]),
#  ('Fasting glucose_CD+HFD', [1314]),
#  ('Fasting glucose_HFD', [1315]),
#  ('Fat gain_17-20 weeks, female on HFD', [4217]),
#  ('Fat gain_17-20 weeks, female+male on HFD', [4216]),
#  ('Fat gain_17-20 weeks, male on HFD', [4218]),
#  ('Fat gain_7-10 weeks, female on HFD', [4219]),
#  ('Fat gain_7-10 weeks, female+male on HFD', [2327]),
#  ('Fat gain_7-10 weeks, male on HFD', [2326]),
#  ('Fat mass percentage_PostWheel_CD', [2197]),
#  ('Fat mass percentage_PostWheel_HFD', [2199]),
#  ('Fat mass percentage_PreWheel_CD', [2203]),
#  ('Fat mass percentage_PreWheel_HFD', [2204]),
#  ('Fat mass percentage_preCLAMS_CD', [2205]),
#  ('Fat mass percentage_preCLAMS_HFD', [2206]),
#  ('Fat mass_PostWheel_CD', [2198]),
#  ('Fat mass_PostWheel_HFD', [2200]),
#  ('Fat mass_PreWheel_CD', [2201]),
#  ('Fat mass_PreWheel_HFD', [2202]),
#  ('Fat mass_preCLAMS_CD', [2207]),
#  ('Fat mass_preCLAMS_HFD', [2208]),
#  ('Fat weight around the neck at 20 weeks in female on HFD', [2329]),
#  ('Fat weight around the neck at 20 weeks in female+male on HFD', [2328]),
#  ('Fat weight around the neck at 20 weeks in male on HFD', [2330]),
#  ('Fat weight in the visceral organs (liver, lung) at 20 weeks in female on HFD',
#   [4220]),
#  ('Fat weight in the visceral organs (liver, lung) at 20 weeks in female+male on HFD',
#   [2331]),
#  ('Fat weight in the visceral organs (liver, lung) at 20 weeks in male on HFD',
#   [2332]),
#  ('Fear conditioning behavior', [344]),
#  ('Fear conditioning response',
#   [345,
#    346,
#    282,
#    347,
#    349,
#    348,
#    2811,
#    2813,
#    2812,
#    350,
#    2815,
#    2814,
#    2816,
#    2818,
#    2817,
#    351,
#    353,
#    352,
#    354,
#    355,
#    283,
#    356,
#    357,
#    284,
#    358,
#    359,
#    360,
#    362,
#    361,
#    285,
#    287,
#    286,
#    2819,
#    289,
#    288]),
#  ('Fear conditioning, freezing',
#   [3028, 856, 3029, 3030, 1457, 3011, 3012, 841, 1458]),
#  ('Fear response', [3308, 1111, 3309]),
#  ('Femur bone cross-sectional area', [3156, 3157]),
#  ('Femur cortical apparent bone mineral density', [2419, 4282, 4283]),
#  ('Femur cortical area', [4284, 4285, 4286]),
#  ('Femur cortical bone volume fraction', [4287, 4288, 4289]),
#  ('Femur cortical envelop mineralized volume', [2420]),
#  ('Femur cortical envelop mineralized volume  ', [2421, 4290]),
#  ('Femur cortical envelop porosity', [4291, 4293]),
#  ('Femur cortical envelop porosity ', [4292]),
#  ('Femur cortical envelop volume', [2422, 4294]),
#  ('Femur cortical envelop volume  ', [2423]),
#  ('Femur cortical marrow area', [4296, 4297]),
#  ('Femur cortical marrow area  ', [4295]),
#  ('Femur cortical marrow volume  ', [4298, 4299, 4300]),
#  ('Femur cortical material bone mineral density', [2424, 4301, 4302]),
#  ('Femur cortical thickness', [4303]),
#  ('Femur cortical thickness ', [2425, 2426]),
#  ('Femur cortical volume ', [2428]),
#  ('Femur cortical volume  ', [2427, 4304]),
#  ('Femur cross-sectional area', [4305, 4306, 4307]),
#  ('Femur cross-sectional volume ', [4309]),
#  ('Femur cross-sectional volume  ', [4308, 4310]),
#  ('Femur length', [2429, 4312]),
#  ('Femur length ', [4311]),
#  ('Femur material bone mineral density ', [2430, 4313, 4314]),
#  ('Femur mineralized volume ', [4315]),
#  ('Femur mineralized volume  ', [4316, 4317]),
#  ('Femur moment of inertia',
#   [2431, 2432, 4318, 2433, 2434, 4319, 2436, 2438, 2439, 2440]),
#  ('Femur moment of inertia  ', [2435, 2437]),
#  ('Femur polar moment of inertia', [2441, 2442, 4320]),
#  ('Femur trabecular apparent bone mineral density', [2444]),
#  ('Femur trabecular apparent bone mineral density ', [4321]),
#  ('Femur trabecular apparent bone mineral densityd', [2443]),
#  ('Femur trabecular bone connectivity density', [4323, 4324]),
#  ('Femur trabecular bone connectivity density ', [4322]),
#  ('Femur trabecular bone degree of anisotropy', [4325, 2445, 4326]),
#  ('Femur trabecular bone structural model index', [2446, 2447, 4327]),
#  ('Femur trabecular bone volume fraction', [4328, 2448, 2449]),
#  ('Femur trabecular material bone mineral density', [2450, 4329, 2451]),
#  ('Femur trabecular mineralized bone volume', [4330]),
#  ('Femur trabecular mineralized bone volume ', [4331, 2452]),
#  ('Femur trabecular number', [4332, 2453, 2454]),
#  ('Femur trabecular seperation', [4333, 2455, 2456]),
#  ('Femur trabecular thickness', [4334, 2457, 4335]),
#  ('Femur trabecular total volume', [2458, 4336]),
#  ('Femur trabecular total volume and female', [4337]),
#  ('Fibrosis susceptibility after carbon tetrachloride challenge',
#   [2526,
#    2527,
#    2528,
#    16,
#    2529,
#    17,
#    18,
#    2530,
#    19,
#    2531,
#    2532,
#    20,
#    21,
#    2533,
#    2534,
#    2535,
#    22,
#    2536,
#    2537,
#    2538,
#    2539,
#    2540,
#    2541,
#    2542,
#    2543,
#    2544,
#    2545,
#    2546,
#    2547,
#    2548]),
#  ('Filiform papillae number', [846]),
#  ('Fimbria volume', [3001]),
#  ('Firmicutes (phylum) proportion', [182]),
#  ('Floor preference baseline', [3363, 3364, 3365]),
#  ('Food Intake_17-20 weeks, female on HFD', [4221]),
#  ('Food Intake_17-20 weeks, female+male on HFD', [2333]),
#  ('Food Intake_7-10 weeks, female on HFD', [4222]),
#  ('Food Intake_7-10 weeks, female+male on HFD', [2334]),
#  ('Food Intake_7-10 weeks, male on HFD', [2335]),
#  ('Food intake in 24 h, metabolic cage_CD', [1783]),
#  ('Food intake in 24 h, metabolic cage_CD_kCal', [1784]),
#  ('Food intake in 24 h, metabolic cage_HFD', [3806]),
#  ('Food intake in 24 h, metabolic cage_HFD_kCal', [3807]),
#  ('Food intake in 24 h, standard housing cage_CD', [3808]),
#  ('Food intake in 24 h, standard housing cage_CD_kCal', [1785]),
#  ('Food intake in 24 h, standard housing cage_HFD', [3809]),
#  ('Food intake in 24 h, standard housing cage_HFD_kCal', [1786]),
#  ('Food intake, female', [123]),
#  ('Food intake, male', [2654]),
#  ('Food intake/body weight_CD', [1787]),
#  ('Food intake/body weight_HFD', [3810]),
#  ('Food intake_17-20 weeks, male on HFD', [2234]),
#  ('Forebrain weight', [1798]),
#  ('Fraction of somatic cell nuclear transfer embryos', [71, 72]),
#  ('Free Fatty Acid_zscore_CD', [3550]),
#  ('Free Fatty Acid_zscore_CD+HFD', [3549]),
#  ('Free fatty acid_zscore_HFD', [3552]),
#  ('Free fatty acids_CD', [3560]),
#  ('Free fatty acids_HFD', [1406]),
#  ('GR-1+ CD11b+ cells as a percentage of CD45 cells', [4010]),
#  ('Gastrocnemius muscle mass', [903, 929, 904]),
#  ('Gastrocnemius muscle mass, percentage_CD', [4422]),
#  ('Gastrocnemius muscle mass, percentage_HFD', [2460]),
#  ('Gastrocnemius muscle mass_20-week', [2674, 141]),
#  ('Gastrocnemius muscle mass_CD', [2459]),
#  ('Gastrocnemius muscle mass_HFD', [4338]),
#  ('Gastrocnemius muscle weight', [930]),
#  ('Geniculate nuclei volume of thalamus', [821]),
#  ('Globotriaosylsphingosine (without sphingomyelinase) in plasma_CD+HFD',
#   [1283]),
#  ('Globotriaosylsphingosine (without sphingomyelinase) in plasma_HFD', [1284]),
#  ('Globotriaosylsphingosine (without sphingomyelinase)in plasma_CD', [1285]),
#  ('Globotriaosylsphingosine in liver_CD', [2125]),
#  ('Globotriaosylsphingosine in liver_CD+HFD', [2124]),
#  ('Globotriaosylsphingosine in liver_HFD', [4082]),
#  ('Globotriaosylsphingosine/Ceramide in liver_CD', [4089]),
#  ('Globotriaosylsphingosine/Ceramide in liver_CD+HFD', [2135]),
#  ('Globotriaosylsphingosine/Ceramide in liver_HFD', [2136]),
#  ('Globotriaosylsphingosine/Ceramide in plasma_CD', [1338]),
#  ('Globotriaosylsphingosine/Ceramide in plasma_CD+HFD', [1336]),
#  ('Globotriaosylsphingosine/Ceramide in plasma_HFD', [1337]),
#  ('Globotriaosylsphingosine/Gluco(galacto)sylceramide in liver_CD', [2138]),
#  ('Globotriaosylsphingosine/Gluco(galacto)sylceramide in liver_CD+HFD',
#   [2137]),
#  ('Globotriaosylsphingosine/Gluco(galacto)sylceramide in liver_HFD', [4090]),
#  ('Globotriaosylsphingosine/Gluco(galacto)sylceramide in plasma_CD', [3504]),
#  ('Globotriaosylsphingosine/Gluco(galacto)sylceramide in plasma_CD+HFD',
#   [1339]),
#  ('Globotriaosylsphingosine/Gluco(galacto)sylceramide in plasma_HFD', [1340]),
#  ('Globus pallidus volume', [828]),
#  ('Glomerular section area', [4455]),
#  ('Gluco(galacto)sylceramide in liver_CD', [2127]),
#  ('Gluco(galacto)sylceramide in liver_CD+HFD', [4083]),
#  ('Gluco(galacto)sylceramide in liver_HFD', [2126]),
#  ('Gluco(galacto)sylceramide in plasma_CD', [1287]),
#  ('Gluco(galacto)sylceramide in plasma_CD+HFD', [1286]),
#  ('Gluco(galacto)sylceramide in plasma_HFD', [3471]),
#  ('Gluco(galacto)sylceramide/Ceramide in liver_CD', [4092]),
#  ('Gluco(galacto)sylceramide/Ceramide in liver_CD+HFD', [4091]),
#  ('Gluco(galacto)sylceramide/Ceramide in liver_HFD', [2139]),
#  ('Gluco(galacto)sylceramide/Ceramide in plasma_CD', [1342]),
#  ('Gluco(galacto)sylceramide/Ceramide in plasma_CD+HFD', [3505]),
#  ('Gluco(galacto)sylceramide/Ceramide in plasma_HFD', [1341]),
#  ('Gluco(galacto)sylsphingosine in liver_CD', [4084]),
#  ('Gluco(galacto)sylsphingosine in liver_CD+HFD', [2128]),
#  ('Gluco(galacto)sylsphingosine in liver_HFD', [2129]),
#  ('Gluco(galacto)sylsphingosine/Gluco(galacto)sylceramide in liver_CD',
#   [4093]),
#  ('Gluco(galacto)sylsphingosine/Gluco(galacto)sylceramide in liver_CD+HFD',
#   [2140]),
#  ('Gluco(galacto)sylsphingosine/Gluco(galacto)sylceramide in liver_HFD',
#   [2141]),
#  ('Glutamate in plasma_CD ', [3473]),
#  ('Glutamate in plasma_CD+HFD', [3472]),
#  ('Glutamate in plasma_HFD ', [1288]),
#  ('Glutamine in plasma_CD ', [3475]),
#  ('Glutamine in plasma_CD+HFD', [3474]),
#  ('Glutamine in plasma_HFD ', [1289]),
#  ('Glycemia after overnight fast_CD ', [2235]),
#  ('Glycemia after overnight fast_HFD ', [2236]),
#  ('Glycine in plasma_CD ', [1292]),
#  ('Glycine in plasma_CD+HFD', [1290]),
#  ('Glycine in plasma_HFD ', [1291]),
#  ('Glycine taste response', [1205]),
#  ('Glycogen content in liver', [4223]),
#  ('Glycogen content in muscle', [4224]),
#  ('Gr-1-NKp46- CD11b+ as a percentage of CD45+ cells', [4011]),
#  ('Granulocyte colony stimulating factor induced progenitor cell mobilization',
#   [3217]),
#  ('Growth of syngeneic breast cancer tumors day 10 ', [3158]),
#  ('Growth of syngeneic breast cancer tumors day 15 ', [3159]),
#  ('Growth of syngeneic breast cancer tumors day 25', [951]),
#  ('H1N1 influenza A virus',
#   [2021,
#    2022,
#    165,
#    166,
#    167,
#    2023,
#    2024,
#    2025,
#    2026,
#    2027,
#    2028,
#    2029,
#    168,
#    2030,
#    2031,
#    2032,
#    2033,
#    2034,
#    2035,
#    2036,
#    4019,
#    4020,
#    4021,
#    4022,
#    4023,
#    4024,
#    2013,
#    4025,
#    815,
#    816]),
#  ('HDL_CD', [1407]),
#  ('HDL_CD_old', [941]),
#  ('HDL_HFD', [1408]),
#  ('HDL_HFD_old', [940]),
#  ('HDL_zscore_CD', [3551]),
#  ('HDL_zscore_CD+HFD', [1391]),
#  ('HDL_zscore_HFD', [1392]),
#  ('Habituation', [936]),
#  ('Haloperidol response', [1142]),
#  ('Handling-induced convulsions', [1143]),
#  ('Heart mass, percentage_CD', [1438]),
#  ('Heart mass, percentage_HFD', [1439]),
#  ('Heart mass_CD', [1428]),
#  ('Heart mass_HFD', [1429]),
#  ('Heart rate, female', [115]),
#  ('Heart rate, male', [116]),
#  ('Heart rate_CD', [1435]),
#  ('Heart rate_HFD', [1436]),
#  ('Heart weight', [1430, 1431, 1432]),
#  ('Heart weight at 20 weeks in female on HFD', [2336]),
#  ('Heart weight at 20 weeks in female+male on HFD', [4225]),
#  ('Heart weight at 20 weeks in male on HFD', [4226]),
#  ('Hematocrit', [2706, 201, 202, 203, 2707]),
#  ('Hematocrit, female', [3043, 2620]),
#  ('Hematocrit, male', [3044, 87]),
#  ('Hematocrit, male and female', [3053]),
#  ('Hematocrit_CD', [3963]),
#  ('Hematocrit_HFD', [3964]),
#  ('Hematopoietic stem cell and progenitor cell number', [914]),
#  ('Hematopoietic stem cell and progenitor cell proliferative capacity', [969]),
#  ('Hematopoietic stem cell number', [876]),
#  ('Hematopoietic stem cell pool size', [901]),
#  ('Hematopoietic stem cells and progenitor cells', [915, 3105, 3188, 970]),
#  ('Hemoglobin', [209, 204, 205, 206, 207, 208, 2708]),
#  ('Hemoglobin concentration distribution width_CD', [1959]),
#  ('Hemoglobin concentration distribution width_HFD', [3965]),
#  ('Hemoglobin in female', [872]),
#  ('Hemoglobin in male', [3046]),
#  ('Hemoglobin in male and female', [3045]),
#  ('Hemoglobin, female', [2621]),
#  ('Hemoglobin, male', [88]),
#  ('Hemoglobin_CD', [3966]),
#  ('Hemoglobin_HFD', [1960]),
#  ('Hepatic lipid peroxidation', [3194]),
#  ('Hepatocellular carcinoma tumor multiplicity', [3354, 3355]),
#  ('Hepatocyte damage',
#   [53, 2599, 2600, 54, 2602, 2601, 55, 56, 57, 2604, 2603, 2605]),
#  ('Hepatocyte general viability', [4106, 2164]),
#  ('Hepatocyte injury assay', [2165, 4107]),
#  ('Hepatocyte phase I metabolic activity', [2166]),
#  ('Hepatocyte phase II metabolic activity', [2167, 4108]),
#  ('Hepatocyte plating efficiency', [2168]),
#  ('Hepatocyte viability', [4109]),
#  ('Herpes simplex virus 1 ocular pathogenesis', [2077]),
#  ('Herpes simplex virus type 1',
#   [2078, 2079, 2080, 2081, 2082, 4058, 4059, 4061, 4060, 2083, 2084]),
#  ('Hexosaminidase activity_CD', [4086]),
#  ('Hexosaminidase activity_CD+HFD', [4085]),
#  ('Hexosaminidase activity_HFD', [2130]),
#  ('High affinity choline uptake in frontal cortex', [1164]),
#  ('High affinity choline uptake in hippocampus ', [3358]),
#  ('High affinity choline uptake in striatum', [1165]),
#  ('High frequency hearing loss', [3269, 3270, 3271, 3272, 3273, 3274]),
#  ('High mature reticulocytes, percentage_CD', [1961]),
#  ('High mature reticulocytes, percentage_HFD', [1963]),
#  ('High mature reticulocytes_CD', [1962]),
#  ('High mature reticulocytes_HFD', [1964]),
#  ('High-dose total body gamma-irradiation survival', [4433]),
#  ('Hindbrain medulla weight', [1799]),
#  ('Hindbrain weight', [3824]),
#  ('Hip cartilage aggrecan 1 mRNA transcript abundance', [2501]),
#  ('Hip cartilage cartilage oligomeric matrix protein mRNA transcript abundance',
#   [2502]),
#  ('Hip cartilage collagen, type II, alpha 1 mRNA transcript abundance',
#   [4424]),
#  ('Hip cartilage endothelial PAS domain protein 1 mRNA transcript abundance',
#   [4425]),
#  ('Hip cartilage matrix metallopeptidase 13 mRNA transcript abundance',
#   [2503]),
#  ('Hippocampus bilateral weight', [1002, 1001]),
#  ('Hippocampus dentate gyrus cells positive for calretinin protein', [259]),
#  ('Hippocampus dentate gyrus cells positive for doublecortin protein', [2746]),
#  ('Hippocampus dentate gyrus granule cell layer volume', [3132]),
#  ('Hippocampus dentate gyrus volume', [938]),
#  ('Hippocampus granule cell density', [1003]),
#  ('Hippocampus granule cell number', [965, 1004]),
#  ('Hippocampus mossy fiber pathway', [1151]),
#  ('Hippocampus mossy fiber pathway volume',
#   [1800, 1150, 3344, 3345, 2747, 2748, 3346, 2749, 3347, 2750, 3348, 2751]),
#  ('Hippocampus network activity in vitro', [253, 254, 255, 256, 257, 258]),
#  ('Hippocampus proper volume', [3133]),
#  ('Hippocampus pyramidal cell layer volume', [939]),
#  ('Hippocampus residual weight', [81]),
#  ('Hippocampus volume', [829]),
#  ('Hippocampus volume, total', [3134]),
#  ('Hippocampus weight', [1005]),
#  ('Hippocampus, dorsal hippocampus volume', [880]),
#  ('Hippocampus, ventral hippocampus volume', [881, 882]),
#  ('Home cage activity', [3311]),
#  ('Hspa5 expression from denoised', [1952]),
#  ('Hydronephrosis', [1190]),
#  ('Hypothalamus volume', [830]),
#  ('IFN-g cytokine in plasma', [3561]),
#  ('IFNa cytokine expression', [1]),
#  ('IGTT_0min, female', [2658]),
#  ...]
